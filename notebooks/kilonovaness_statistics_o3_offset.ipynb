# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
tablefile_dir = "/mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova"
tablefile_name = "TransientTable.csv"

tablefiles = [os.path.join(tablefile_dir, event_dir, tablefile_name) for event_dir in os.listdir(tablefile_dir) if os.path.exists(os.path.join(tablefile_dir, event_dir, tablefile_name) )]

print("\n".join(tablefiles))
# Out:
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S190426c_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S190901ap_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S190910d_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S190910h_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S190930s_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S190930t_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S191109d_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S191110x_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S191212q_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S191215w_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S191220af_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200105ae_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200108v_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200112r_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200115j_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200116ah_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200128_rev_S200128d/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200213t_rev_1/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200219ac_rev_0/TransientTable.csv
# /mnt/c/Users/Public/Documents/Uni/master/masterarbeit/ampel/ampel-results/ligo-kilonova/S200225q_rev_1/TransientTable.csv

# %%
all_data = pd.DataFrame()

for file in tablefiles:
    #print(file)
    df_tmp = pd.read_csv(file, sep=";")
    #print(rate_tmp)
    all_data = pd.concat([all_data, df_tmp])

#all_data["Map name"]

# %%
alertcount_df = pd.DataFrame()

for map_name in all_data["Map name"].unique():
    #print(map_name)
    temp_df = all_data[all_data["Map name"] == map_name]
    new_temp_df = pd.DataFrame(temp_df[["Map name", "Unfiltered alerts", "Queried alerts", "Map area", "Map dist", "Map dist unc"]]).iloc[[0]]
    
    new_temp_df["Filtered alerts"] = len(temp_df)
    #print(new_temp_df)
    alertcount_df = pd.concat([alertcount_df, new_temp_df])

alertcount_df["Fraction queried"] = alertcount_df["Queried alerts"] / alertcount_df["Unfiltered alerts"]
alertcount_df["Fraction filtered"] = alertcount_df["Filtered alerts"] / alertcount_df["Unfiltered alerts"]


tmp_total_dict = {"Unfiltered": alertcount_df["Unfiltered alerts"].sum(),
                                    "Unfiltered mean": alertcount_df["Unfiltered alerts"].mean(),
                                    "Queried": alertcount_df["Queried alerts"].sum(),
                                    "Queried fraction mean": alertcount_df["Fraction queried"].mean(),
                                    "Filtered": alertcount_df["Filtered alerts"].sum(),
                                    "Filtered fraction mean": alertcount_df["Fraction filtered"].mean(),
                                    "Mean map area": alertcount_df["Map area"].mean(),
                                    "Mean map dist": alertcount_df["Map dist"].mean(),
                                    "Mean map dist unc": alertcount_df["Map dist unc"].mean()}

total_alertcount_df = pd.DataFrame.from_dict([tmp_total_dict])
total_alertcount_df["Fraction queried"] = total_alertcount_df["Queried"] / total_alertcount_df["Unfiltered"]
total_alertcount_df["Fraction filtered"] = total_alertcount_df["Filtered"] / total_alertcount_df["Unfiltered"]

print(len(alertcount_df))

total_alertcount_df
# Out:
# 20
#    Unfiltered  Unfiltered mean   Queried  Queried fraction mean  Filtered  \
# 0   3463655.0    182297.631579  677731.0               0.217968       823
#
#    Filtered fraction mean  Mean map area  Mean map dist  Mean map dist unc  \
# 0                0.000906    5107.024459     802.187191         240.159842
#
#    Fraction queried  Fraction filtered
# 0          0.195669           0.000238

# %%
mean_df = total_alertcount_df[["Filtered fraction mean", "Queried fraction mean"]] * 100
total_frac_df = total_alertcount_df[["Fraction filtered", "Fraction queried"]] * 100

print(mean_df.keys())
print(mean_df.values[0])

xes = np.array([0, 1])
offset = 0.3

width = 0.3

xticks = ["Filtered", "Queried"]

rects_1 = plt.bar(xes, mean_df.values[0], label="Mean of fractions \n(fraction taken per map, then mean)", width=width)
rects_2 = plt.bar(xes + offset, total_frac_df.values[0], label="Fraction of means \n(mean of absolutes over maps, then fraction)", width=width)

plt.xticks(xes+width/2, xticks)

plt.yscale("log")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel("Mean fraction of all events in range (%)")


plt.bar_label(rects_2)
plt.bar_label(rects_1)
# Out:
# Index(['Filtered fraction mean', 'Queried fraction mean'], dtype='object')
# [ 0.09056546 21.79681778]
# [Text(0, 0, '0.0905655'), Text(0, 0, '21.7968')]

# %%
rate_df = pd.DataFrame()

for file in tablefiles:
    #print(file)
    df_tmp = pd.read_csv(file, sep=";")
    df_tmp["kn-1000-rate"] = np.array([np.count_nonzero(df_tmp["Kilonovaness"] == kilonovaness) for kilonovaness in df_tmp["Kilonovaness"]]) / df_tmp["Map area"] * 1000

    rate_tmp = np.array([np.count_nonzero(df_tmp["Kilonovaness"] == kilonovaness) for kilonovaness in df_tmp["Kilonovaness"].unique()]) / df_tmp["Map area"][0] * 1000

    tmp_rate_df = pd.DataFrame({"Kilonovaness": df_tmp["Kilonovaness"].unique(),"kn-1000-rate": rate_tmp, "map_name": df_tmp["Map name"][0], "Map dist": df_tmp["Map dist"][0]})

    #print(rate_tmp)
    rate_df = pd.concat([rate_df, tmp_rate_df])


rate_df.head(20)
# Out:
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 0             23      1.035013   S190426c.fits.gz,1  422.713675
# 1             22      1.035013   S190426c.fits.gz,1  422.713675
# 2             21      1.552520   S190426c.fits.gz,1  422.713675
# 3             20      0.517507   S190426c.fits.gz,1  422.713675
# 4             18      1.035013   S190426c.fits.gz,1  422.713675
# 5             17      0.517507   S190426c.fits.gz,1  422.713675
# 6             16      0.517507   S190426c.fits.gz,1  422.713675
# 7             15      4.140053   S190426c.fits.gz,1  422.713675
# 8             14      2.070026   S190426c.fits.gz,1  422.713675
# 9             13      2.070026   S190426c.fits.gz,1  422.713675
# 10            12      2.070026   S190426c.fits.gz,1  422.713675
# 11            11      0.517507   S190426c.fits.gz,1  422.713675
# 12            10      1.035013   S190426c.fits.gz,1  422.713675
# 13             9      1.552520   S190426c.fits.gz,1  422.713675
# 14             6      0.517507   S190426c.fits.gz,1  422.713675
# 15             4      0.517507   S190426c.fits.gz,1  422.713675
# 16             3      0.517507   S190426c.fits.gz,1  422.713675
# 17             1      0.517507   S190426c.fits.gz,1  422.713675
# 0             24      0.073460  S190901ap.fits.gz,0  242.203653
# 1             23      0.073460  S190901ap.fits.gz,0  242.203653

# %%
distance_mins = [0, 100, 200, 400, 600]
distance_maxs = [100, 200, 400,600, np.inf]
n = len(distance_mins)
m = len(distance_maxs)

binned_data = np.empty((n, m), dtype=pd.DataFrame)

#print(binned_data)

for k in range(n):
    for j in range(k, m):

        dist_min = distance_mins[k]
        dist_max = distance_maxs[j]
        #print(f"From {dist_min} to {dist_max} Mpc")


        kilonovaness_rate = pd.DataFrame(columns=["Kilonovaness", "rate-1000", "std-1000", "entries"])
        #print(kilonovaness_rate.head())
        #print(data["Kilonovaness"].unique())

        lim_data = rate_df[np.logical_and(rate_df["Map dist"] >= dist_min, rate_df["Map dist"] < dist_max)]

        for kilonovaness in lim_data["Kilonovaness"].unique():
            #print(kilonovaness)
            tmp = lim_data[lim_data["Kilonovaness"] == kilonovaness]

            data_dict = {"Kilonovaness": [kilonovaness], "rate-1000": [np.mean(tmp["kn-1000-rate"].values)], "std-1000": [np.std(tmp["kn-1000-rate"].values)], "entries":[len(tmp["kn-1000-rate"].values)]}
            #print(data_dict)
            mini_tmp = pd.DataFrame.from_dict(data_dict)

            kilonovaness_rate = pd.concat([kilonovaness_rate, mini_tmp])
            kilonovaness_rate = kilonovaness_rate.sort_values(by=["Kilonovaness"], ascending=True)
        
        binned_data[k, j] = kilonovaness_rate
        
        # print(kilonovaness_rate)

print(kilonovaness_rate.head(5))

#print(binned_data)

fig, axs = plt.subplots(ncols=m, nrows=n, figsize=(10, 10),
                        layout="constrained", sharex=True, sharey=True, subplot_kw={"xticks": [0, 5, 10, 15, 20, 25], "yticks": [0, 5, 10, 15]})
# fill plots
for row in range(n):
    for col in range(m):
        if (binned_data[row, col] is not None):
            #print()
            axs[-row-1, -col-1].plot(binned_data[row, col]["Kilonovaness"], binned_data[row, col]["rate-1000"], marker=".", label="Occurrences")
            #secax_x2 = axs[-row-1, -col-1].twinx()
            axs[-row-1, -col-1].plot(binned_data[row, col]["Kilonovaness"], binned_data[row, col]["std-1000"], marker=".", color="orange", label="Standard deviation")
            #secax_x2.plot(binned_data[row, col]["Kilonovaness"], binned_data[row, col]["std-1000"], marker=".", color="orange")
            axs[-row-1, -col-1].set_title(f"{distance_mins[row]}-{distance_maxs[col]} Mpc", fontsize=8)
            axs[-row-1, -col-1].grid()
        else:
            axs[-row-1, -col-1].set_visible(False)
        #pass

handles, labels = axs[-row-1, -col-1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center right')

fig.suptitle('Occurences of Kilonovaness per area for distance intervals')
fig.supxlabel("Kilonovaness")
fig.supylabel("Occurences per 1000 sq. deg.", ha="left")

# dummy axes 2 for right ylabel
# ax = fig.add_subplot(1, 1, 1)
# ax.set_xticks([])
# ax.set_yticks([])
# [ax.spines[side].set_visible(False) for side in ('left', 'top', 'right', 'bottom')]
# ax.patch.set_visible(False)
# ax.yaxis.set_label_position('right')
# ax.set_ylabel('Standard deviation', labelpad=30, fontsize=12)


fig.tight_layout()
plt.show()
# Out:
#   Kilonovaness  rate-1000  std-1000 entries
# 0            1   2.032533  2.711632       4
# 0            3   0.500529  0.000000       1
# 0            6   0.520413  0.220246       3
# 0            8   0.416815  0.255506       2
# 0            9   2.003419  1.358184       2
# /tmp/ipykernel_309/3565148529.py:77: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %%
dist_min = 100
dist_max = 600
#print(f"From {dist_min} to {dist_max} Mpc")


kilonovaness_rate = pd.DataFrame(columns=["Kilonovaness", "rate-1000", "std-1000", "entries"])
#print(kilonovaness_rate.head())
#print(data["Kilonovaness"].unique())

lim_data = rate_df[np.logical_and(rate_df["Map dist"] >= dist_min, rate_df["Map dist"] < dist_max)]

lim_data.head()


for kilonovaness in lim_data["Kilonovaness"].unique()[:]:
    print("KILONVANESS:", kilonovaness)
    tmp = lim_data[lim_data["Kilonovaness"] == kilonovaness]
    print(tmp)

    print(tmp["kn-1000-rate"])
    print(tmp["Kilonovaness"])

    data_dict = {"Kilonovaness": [kilonovaness], "rate-1000": [np.mean(tmp["kn-1000-rate"].values)], "std-1000": [np.std(tmp["kn-1000-rate"].values)], "entries":[len(tmp["kn-1000-rate"].values)]}
    print(data_dict)
    mini_tmp = pd.DataFrame.from_dict(data_dict)

    kilonovaness_rate = pd.concat([kilonovaness_rate, mini_tmp])
    kilonovaness_rate = kilonovaness_rate.sort_values(by=["Kilonovaness"], ascending=True)
    print()

lim_data.head(20)

print(kilonovaness_rate)
# Out:
# KILONVANESS: 23
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 0            23      1.035013   S190426c.fits.gz,1  422.713675
# 1            23      0.073460  S190901ap.fits.gz,0  242.203653
# 0            23      0.041288   S190930t.fits.gz,0  108.485191
# 1            23      0.386565   S200213t.fits.gz,1  223.549169
# 0    1.035013
# 1    0.073460
# 0    0.041288
# 1    0.386565
# Name: kn-1000-rate, dtype: float64
# 0    23
# 1    23
# 0    23
# 1    23
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [23], 'rate-1000': [0.38408137732004055], 'std-1000': [0.3992843191573808], 'entries': [4]}
#
# KILONVANESS: 22
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 1            22      1.035013   S190426c.fits.gz,1  422.713675
# 1            22      0.082575   S190930t.fits.gz,0  108.485191
# 1            22      0.129551  S200105ae.fits.gz,1  265.096629
# 2            22      0.773130   S200213t.fits.gz,1  223.549169
# 1    1.035013
# 1    0.082575
# 1    0.129551
# 2    0.773130
# Name: kn-1000-rate, dtype: float64
# 1    22
# 1    22
# 1    22
# 2    22
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [22], 'rate-1000': [0.5050673308773248], 'std-1000': [0.4099428591134999], 'entries': [4]}
#
# KILONVANESS: 21
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 2            21      1.552520   S190426c.fits.gz,1  422.713675
# 2            21      0.073460  S190901ap.fits.gz,0  242.203653
# 2            21      0.082575   S190930t.fits.gz,0  108.485191
# 2            21      0.388652  S200105ae.fits.gz,1  265.096629
# 0            21      1.174069   S200108v.fits.gz,1  408.599403
# 2    1.552520
# 2    0.073460
# 2    0.082575
# 2    0.388652
# 0    1.174069
# Name: kn-1000-rate, dtype: float64
# 2    21
# 2    21
# 2    21
# 2    21
# 0    21
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [21], 'rate-1000': [0.6542551464276877], 'std-1000': [0.6019588069861637], 'entries': [5]}
#
# KILONVANESS: 20
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 3            20      0.517507   S190426c.fits.gz,1  422.713675
# 0            20      0.041278   S190910h.fits.gz,0  241.450383
# 3            20      0.082575   S190930t.fits.gz,0  108.485191
# 3            20      0.129551  S200105ae.fits.gz,1  265.096629
# 3            20      0.386565   S200213t.fits.gz,1  223.549169
# 3    0.517507
# 0    0.041278
# 3    0.082575
# 3    0.129551
# 3    0.386565
# Name: kn-1000-rate, dtype: float64
# 3    20
# 0    20
# 3    20
# 3    20
# 3    20
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [20], 'rate-1000': [0.2314950507674652], 'std-1000': [0.18686987532970564], 'entries': [5]}
#
# KILONVANESS: 18
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 4            18      1.035013   S190426c.fits.gz,1  422.713675
# 2            18      0.041278   S190910h.fits.gz,0  241.450383
# 5            18      0.289013   S190930t.fits.gz,0  108.485191
# 4            18      0.129551  S200105ae.fits.gz,1  265.096629
# 0            18      1.306943   S200115j.fits.gz,0  340.223830
# 5            18      1.159695   S200213t.fits.gz,1  223.549169
# 4    1.035013
# 2    0.041278
# 5    0.289013
# 4    0.129551
# 0    1.306943
# 5    1.159695
# Name: kn-1000-rate, dtype: float64
# 4    18
# 2    18
# 5    18
# 4    18
# 0    18
# 5    18
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [18], 'rate-1000': [0.6602489316328364], 'std-1000': [0.5181201050395733], 'entries': [6]}
#
# KILONVANESS: 17
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 5            17      0.517507   S190426c.fits.gz,1  422.713675
# 3            17      0.247666   S190910h.fits.gz,0  241.450383
# 6            17      0.371589   S190930t.fits.gz,0  108.485191
# 0            17      1.356711   S191110x.fits.gz,0  203.976886
# 5            17      1.036406  S200105ae.fits.gz,1  265.096629
# 6            17      1.932825   S200213t.fits.gz,1  223.549169
# 5    0.517507
# 3    0.247666
# 6    0.371589
# 0    1.356711
# 5    1.036406
# 6    1.932825
# Name: kn-1000-rate, dtype: float64
# 5    17
# 3    17
# 6    17
# 0    17
# 5    17
# 6    17
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [17], 'rate-1000': [0.9104504412066352], 'std-1000': [0.5978188167780285], 'entries': [6]}
#
# KILONVANESS: 16
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 6            16      0.517507   S190426c.fits.gz,1  422.713675
# 4            16      0.165110   S190910h.fits.gz,0  241.450383
# 7            16      0.701890   S190930t.fits.gz,0  108.485191
# 6            16      1.165957  S200105ae.fits.gz,1  265.096629
# 7            16      0.773130   S200213t.fits.gz,1  223.549169
# 6    0.517507
# 4    0.165110
# 7    0.701890
# 6    1.165957
# 7    0.773130
# Name: kn-1000-rate, dtype: float64
# 6    16
# 4    16
# 7    16
# 6    16
# 7    16
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [16], 'rate-1000': [0.6647186593110301], 'std-1000': [0.3273084108169049], 'entries': [5]}
#
# KILONVANESS: 15
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 7            15      4.140053   S190426c.fits.gz,1  422.713675
# 5            15      0.288943   S190910h.fits.gz,0  241.450383
# 8            15      0.578027   S190930t.fits.gz,0  108.485191
# 7            15      2.072812  S200105ae.fits.gz,1  265.096629
# 8            15      0.773130   S200213t.fits.gz,1  223.549169
# 7    4.140053
# 5    0.288943
# 8    0.578027
# 7    2.072812
# 8    0.773130
# Name: kn-1000-rate, dtype: float64
# 7    15
# 5    15
# 8    15
# 7    15
# 8    15
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [15], 'rate-1000': [1.5705929297725496], 'std-1000': [1.4225405920702066], 'entries': [5]}
#
# KILONVANESS: 14
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 8            14      2.070026   S190426c.fits.gz,1  422.713675
# 4            14      0.073460  S190901ap.fits.gz,0  242.203653
# 6            14      1.197051   S190910h.fits.gz,0  241.450383
# 9            14      0.495451   S190930t.fits.gz,0  108.485191
# 1            14      1.356711   S191110x.fits.gz,0  203.976886
# 8            14      2.072812  S200105ae.fits.gz,1  265.096629
# 9            14      1.546260   S200213t.fits.gz,1  223.549169
# 8    2.070026
# 4    0.073460
# 6    1.197051
# 9    0.495451
# 1    1.356711
# 8    2.072812
# 9    1.546260
# Name: kn-1000-rate, dtype: float64
# 8    14
# 4    14
# 6    14
# 9    14
# 1    14
# 8    14
# 9    14
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [14], 'rate-1000': [1.258824382884606], 'std-1000': [0.6973899526079207], 'entries': [7]}
#
# KILONVANESS: 13
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 9             13      2.070026   S190426c.fits.gz,1  422.713675
# 5             13      0.220379  S190901ap.fits.gz,0  242.203653
# 7             13      1.568549   S190910h.fits.gz,0  241.450383
# 10            13      0.908328   S190930t.fits.gz,0  108.485191
# 2             13      4.070132   S191110x.fits.gz,0  203.976886
# 9             13      2.591015  S200105ae.fits.gz,1  265.096629
# 10            13      1.932825   S200213t.fits.gz,1  223.549169
# 9     2.070026
# 5     0.220379
# 7     1.568549
# 10    0.908328
# 2     4.070132
# 9     2.591015
# 10    1.932825
# Name: kn-1000-rate, dtype: float64
# 9     13
# 5     13
# 7     13
# 10    13
# 2     13
# 9     13
# 10    13
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [13], 'rate-1000': [1.9087505396724957], 'std-1000': [1.1421048984846198], 'entries': [7]}
#
# KILONVANESS: 12
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 10            12      2.070026   S190426c.fits.gz,1  422.713675
# 6             12      0.146919  S190901ap.fits.gz,0  242.203653
# 8             12      1.485994   S190910h.fits.gz,0  241.450383
# 11            12      0.949615   S190930t.fits.gz,0  108.485191
# 3             12      8.140264   S191110x.fits.gz,0  203.976886
# 10            12      4.663826  S200105ae.fits.gz,1  265.096629
# 11            12      1.546260   S200213t.fits.gz,1  223.549169
# 10    2.070026
# 6     0.146919
# 8     1.485994
# 11    0.949615
# 3     8.140264
# 10    4.663826
# 11    1.546260
# Name: kn-1000-rate, dtype: float64
# 10    12
# 6     12
# 8     12
# 11    12
# 3     12
# 10    12
# 11    12
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [12], 'rate-1000': [2.7147007294380097], 'std-1000': [2.5700314615684783], 'entries': [7]}
#
# KILONVANESS: 11
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 11            11      0.517507   S190426c.fits.gz,1  422.713675
# 7             11      0.146919  S190901ap.fits.gz,0  242.203653
# 9             11      0.371498   S190910h.fits.gz,0  241.450383
# 12            11      1.073478   S190930t.fits.gz,0  108.485191
# 4             11      2.713421   S191110x.fits.gz,0  203.976886
# 0             11      0.190900  S191220af.fits.gz,1  166.195803
# 11            11      1.943261  S200105ae.fits.gz,1  265.096629
# 12            11      1.159695   S200213t.fits.gz,1  223.549169
# 11    0.517507
# 7     0.146919
# 9     0.371498
# 12    1.073478
# 4     2.713421
# 0     0.190900
# 11    1.943261
# 12    1.159695
# Name: kn-1000-rate, dtype: float64
# 11    11
# 7     11
# 9     11
# 12    11
# 4     11
# 0     11
# 11    11
# 12    11
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [11], 'rate-1000': [1.0145849696664537], 'std-1000': [0.8562240712651987], 'entries': [8]}
#
# KILONVANESS: 10
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 12            10      1.035013   S190426c.fits.gz,1  422.713675
# 10            10      0.247666   S190910h.fits.gz,0  241.450383
# 13            10      1.156053   S190930t.fits.gz,0  108.485191
# 5             10     16.280527   S191110x.fits.gz,0  203.976886
# 12            10      0.518203  S200105ae.fits.gz,1  265.096629
# 13            10      0.773130   S200213t.fits.gz,1  223.549169
# 12     1.035013
# 10     0.247666
# 13     1.156053
# 5     16.280527
# 12     0.518203
# 13     0.773130
# Name: kn-1000-rate, dtype: float64
# 12    10
# 10    10
# 13    10
# 5     10
# 12    10
# 13    10
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [10], 'rate-1000': [3.3350987755244343], 'std-1000': [5.797320987973122], 'entries': [6]}
#
# KILONVANESS: 9
#     Kilonovaness  kn-1000-rate            map_name    Map dist
# 13             9      1.552520  S190426c.fits.gz,1  422.713675
# 11             9      0.082555  S190910h.fits.gz,0  241.450383
# 14             9      0.289013  S190930t.fits.gz,0  108.485191
# 6              9     17.637238  S191110x.fits.gz,0  203.976886
# 1              9      2.613887  S200115j.fits.gz,0  340.223830
# 14             9      0.386565  S200213t.fits.gz,1  223.549169
# 13     1.552520
# 11     0.082555
# 14     0.289013
# 6     17.637238
# 1      2.613887
# 14     0.386565
# Name: kn-1000-rate, dtype: float64
# 13    9
# 11    9
# 14    9
# 6     9
# 1     9
# 14    9
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [9], 'rate-1000': [3.760296407933508], 'std-1000': [6.267850377186759], 'entries': [6]}
#
# KILONVANESS: 6
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 14             6      0.517507   S190426c.fits.gz,1  422.713675
# 14             6      0.041278   S190910h.fits.gz,0  241.450383
# 16             6      0.041288   S190930t.fits.gz,0  108.485191
# 13             6      0.129551  S200105ae.fits.gz,1  265.096629
# 14    0.517507
# 14    0.041278
# 16    0.041288
# 13    0.129551
# Name: kn-1000-rate, dtype: float64
# 14    6
# 14    6
# 16    6
# 13    6
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [6], 'rate-1000': [0.18240564160179207], 'std-1000': [0.19679794023952352], 'entries': [4]}
#
# KILONVANESS: 4
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 15             4      0.517507   S190426c.fits.gz,1  422.713675
# 18             4      0.041288   S190930t.fits.gz,0  108.485191
# 14             4      0.129551  S200105ae.fits.gz,1  265.096629
# 15    0.517507
# 18    0.041288
# 14    0.129551
# Name: kn-1000-rate, dtype: float64
# 15    4
# 18    4
# 14    4
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [4], 'rate-1000': [0.22944832007215332], 'std-1000': [0.20685063367728806], 'entries': [3]}
#
# KILONVANESS: 3
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 16             3      0.517507   S190426c.fits.gz,1  422.713675
# 16             3      0.619164   S190910h.fits.gz,0  241.450383
# 19             3      0.165150   S190930t.fits.gz,0  108.485191
# 15             3      0.129551  S200105ae.fits.gz,1  265.096629
# 16             3      0.386565   S200213t.fits.gz,1  223.549169
# 16    0.517507
# 16    0.619164
# 19    0.165150
# 15    0.129551
# 16    0.386565
# Name: kn-1000-rate, dtype: float64
# 16    3
# 16    3
# 19    3
# 15    3
# 16    3
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [3], 'rate-1000': [0.3635873956126384], 'std-1000': [0.19167102839151184], 'entries': [5]}
#
# KILONVANESS: 1
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 17             1      0.517507   S190426c.fits.gz,1  422.713675
# 17             1      0.041278   S190910h.fits.gz,0  241.450383
# 20             1      0.330301   S190930t.fits.gz,0  108.485191
# 16             1      0.388652  S200105ae.fits.gz,1  265.096629
# 17             1      0.386565   S200213t.fits.gz,1  223.549169
# 17    0.517507
# 17    0.041278
# 20    0.330301
# 16    0.388652
# 17    0.386565
# Name: kn-1000-rate, dtype: float64
# 17    1
# 17    1
# 20    1
# 16    1
# 17    1
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [1], 'rate-1000': [0.3328604869922297], 'std-1000': [0.15818863103759387], 'entries': [5]}
#
# KILONVANESS: 24
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 0            24      0.073460  S190901ap.fits.gz,0  242.203653
# 0            24      0.129551  S200105ae.fits.gz,1  265.096629
# 0            24      0.386565   S200213t.fits.gz,1  223.549169
# 0    0.073460
# 0    0.129551
# 0    0.386565
# Name: kn-1000-rate, dtype: float64
# 0    24
# 0    24
# 0    24
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [24], 'rate-1000': [0.19652513676972602], 'std-1000': [0.13631565184969643], 'entries': [3]}
#
# KILONVANESS: 19
#    Kilonovaness  kn-1000-rate             map_name    Map dist
# 3            19      0.073460  S190901ap.fits.gz,0  242.203653
# 1            19      0.082555   S190910h.fits.gz,0  241.450383
# 4            19      0.041288   S190930t.fits.gz,0  108.485191
# 4            19      0.386565   S200213t.fits.gz,1  223.549169
# 3    0.073460
# 1    0.082555
# 4    0.041288
# 4    0.386565
# Name: kn-1000-rate, dtype: float64
# 3    19
# 1    19
# 4    19
# 4    19
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [19], 'rate-1000': [0.14596687681014564], 'std-1000': [0.13975297875050308], 'entries': [4]}
#
# KILONVANESS: 8
#     Kilonovaness  kn-1000-rate             map_name    Map dist
# 12             8      0.041278   S190910h.fits.gz,0  241.450383
# 15             8      0.082575   S190930t.fits.gz,0  108.485191
# 7              8      2.713421   S191110x.fits.gz,0  203.976886
# 1              8      0.190900  S191220af.fits.gz,1  166.195803
# 12    0.041278
# 15    0.082575
# 7     2.713421
# 1     0.190900
# Name: kn-1000-rate, dtype: float64
# 12    8
# 15    8
# 7     8
# 1     8
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [8], 'rate-1000': [0.7570435039224253], 'std-1000': [1.13083604256995], 'entries': [4]}
#
# KILONVANESS: 7
#     Kilonovaness  kn-1000-rate            map_name    Map dist
# 13             7      0.041278  S190910h.fits.gz,0  241.450383
# 15             7      0.386565  S200213t.fits.gz,1  223.549169
# 13    0.041278
# 15    0.386565
# Name: kn-1000-rate, dtype: float64
# 13    7
# 15    7
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [7], 'rate-1000': [0.2139213374214457], 'std-1000': [0.17264373123073737], 'entries': [2]}
#
# KILONVANESS: 5
#     Kilonovaness  kn-1000-rate            map_name    Map dist
# 15             5      0.123833  S190910h.fits.gz,0  241.450383
# 17             5      0.082575  S190930t.fits.gz,0  108.485191
# 15    0.123833
# 17    0.082575
# Name: kn-1000-rate, dtype: float64
# 15    5
# 17    5
# Name: Kilonovaness, dtype: int64
# {'Kilonovaness': [5], 'rate-1000': [0.10320402806403725], 'std-1000': [0.02062879050808772], 'entries': [2]}
#
#   Kilonovaness  rate-1000  std-1000 entries
# 0            1   0.332860  0.158189       5
# 0            3   0.363587  0.191671       5
# 0            4   0.229448  0.206851       3
# 0            5   0.103204  0.020629       2
# 0            6   0.182406  0.196798       4
# 0            7   0.213921  0.172644       2
# 0            8   0.757044  1.130836       4
# 0            9   3.760296  6.267850       6
# 0           10   3.335099  5.797321       6
# 0           11   1.014585  0.856224       8
# 0           12   2.714701  2.570031       7
# 0           13   1.908751  1.142105       7
# 0           14   1.258824  0.697390       7
# 0           15   1.570593  1.422541       5
# 0           16   0.664719  0.327308       5
# 0           17   0.910450  0.597819       6
# 0           18   0.660249  0.518120       6
# 0           19   0.145967  0.139753       4
# 0           20   0.231495  0.186870       5
# 0           21   0.654255  0.601959       5
# 0           22   0.505067  0.409943       4
# 0           23   0.384081  0.399284       4
# 0           24   0.196525  0.136316       3
